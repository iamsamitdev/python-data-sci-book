# %%
import pandas as pd
import numpy as np

sr = pd.Series([40, 20, 50, 30, 40, 20])
sr.plot.line()

# %%
import pandas as pd
import numpy as np

data = np.random.randint(10, 101, 10)
sr = pd.Series(data, index=list('abcdefghij'))

sr.plot(kind='line', title='Line Plot with Pandas', 
        style='ro--', grid=True, fontsize=16)

# %%
import pandas as pd
import numpy as np

data = np.random.randint(10, 101, 10)
sr = pd.Series(data, index=list('abcdefghij'))

sr.plot.line(style='mD:', grid=True, use_index=False, 
             xticks=np.arange(0, 10, 1),
             yticks=np.arange(0, 110, 10))

# %%
import pandas as pd
import numpy as np

#เลือกเฉพาะจำนวนที่มีค่า 50 ขึ้นไปมาสร้างเป็นกราฟ
data = np.random.randint(10, 101, 20)
sr = pd.Series(data)

sr[sr > 50].plot(kind='line', style='bp--', 
                 grid=True, use_index=False)

# %%
import pandas as pd
import numpy as np

#แสดงกราฟของข้อมูล 10 รายการสุดท้าย
data = np.random.randint(10, 101, 30)
sr = pd.Series(data)

sr.tail(10).plot(kind='line', style='bp--', 
                 grid=True, use_index=True)

# %%
import pandas as pd
import numpy as np

y_tk = np.arange(1.0, 11, 1.5)  #tick ในแนวแกน Y ระหว่าง 1-10 ระยะห่าง 1.5

data1 = [3.75, 4.8, 9.7, 1.50, 6.3, 4.4, 5.5]
sr = pd.Series(data1)

sr.plot.line(style='bo--', grid=True, yticks=y_tk,
             legend=True, label='Data 1')

data2 = np.random.randint(1, 11, 7)
sr2 = pd.Series(data2)

sr2.plot.line(style='mD:', alpha=0.6, 
              grid=True, yticks=y_tk, 
              legend=True, label='Data 2')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn')

plt.rcParams['font.sans-serif'] = 'tahoma'
plt.rcParams['font.family'] = 'tahoma'
#plt.rcParams['font.size'] = 14

data = np.random.randint(10, 101, 7)
idx = ['อาทิตย์', 'จันทร์', 'อังคาร','พุธ', 'พฤหัส', 'ศุกร์', 'เสาร์']
sr = pd.Series(data, index=idx)

sr.plot(kind='line', style='mD--', 
        rot=45, use_index=True, fontsize=16)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn')

data = [3.75, 4.8, 9.7, 3.50, 6.3, 4.4, 5.5]
idx = np.arange(2014, 2021)
sr = pd.Series(data, index=idx)

sr.plot.line(style='gs:', use_index=True,
             yticks=np.arange(0, 11, 1.5))

plt.title('อัตราการว่างงานของประเทศแห่งหนึ่ง', 
          fontname='tahoma', fontsize=16)

plt.ylabel('อัตราการว่างงาน', fontname='tahoma', fontsize=14)
plt.xlabel('ปี ค.ศ.', fontname='tahoma', fontsize=14)
# Out:
# Text(0.5, 0, 'ปี ค.ศ.')

# %%
import pandas as pd
import numpy as np

sr = pd.Series([40, 20, 50, 30, 40, 20],
               index=np.arange(1, 7))

sr.plot.bar(rot=0, use_index=True, color='m')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn')

data = np.random.randint(10, 101, 20)
sr = pd.Series(data)

sr[sr > 50].head(5).plot(kind='barh', use_index=False, 
                         fontsize=14, 
                         xticks=np.arange(0, 100, 15))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn')

font_options = {'family': 'tahoma',
                'weight': 'normal',
                'size': 14}

plt.rc('font', **font_options)

data = np.random.randint(10, 101, 7)
idx = ['อาทิตย์', 'จันทร์', 'อังคาร','พุธ', 'พฤหัส', 'ศุกร์', 'เสาร์']
sr = pd.Series(data, index=idx)

sr.plot(kind='bar', color='b',
        rot=45, use_index=True, fontsize=16)

plt.title('ยอดขายสินค้าในรอบสัปดาห์', fontsize=16, c='g')
plt.xlabel('วัน', fontsize=16, c='m')
plt.ylabel('ยอดขาย', fontsize=16, c='m')
# Out:
# Text(0, 0.5, 'ยอดขาย')

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')

data = [22, 24, 24, 25, 25, 21, 23, 24, 23, 25, 25, 22, 20, 22,
        28, 27, 29, 29, 30, 26, 27, 29, 30, 30, 29, 26,
        33, 34, 34, 32, 31, 31, 34, 35, 33, 32, 32, 34,
        37, 39, 36, 38, 38, 37, 40, 39, 40, 37,
        45, 44, 43, 43, 41, 42, 44, 46, 43, 44,
        50, 47, 48, 47, 46, 49, 50, 48, 46,
        52, 53, 55, 51, 51, 54, 55, 52,
        59, 60, 58, 58, 56]

sr = pd.Series(data)
sr.plot.hist(bins=8, color='c', edgecolor='b')

#plt.ylabel('')   #ถ้าต้องการตัดคำว่า Frequency ในแนวแกน Y ออก ให้ระคำสั่งนี้

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn')

data = [50, 20, 15, 5, 10]
label = ['Chrome', 'Edge', 'Firefox', 'Opera', 'Safari']
sr = pd.Series(data, index=label)

exp = [0, 0.1, 0, 0, 0.2] 

sr.plot(kind='pie', explode=exp, startangle=30, 
        colors=['lightgreen', 'lightgray', 'pink', 
                'cyan', 'lightblue'],
        shadow=True, autopct="%.1f%%",
        fontsize=14)

plt.ylabel('')  #เพื่อตัดคำว่า None ในแนวแกน Y ออกไป
# Out:
# Text(0, 0.5, '')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.subplot(2,2,1)
data1 = [3.75, 4.8, 9.7, 1.50, 6.3, 4.4, 5.5]
sr1 = pd.Series(data1)
ytk = np.arange(1.0, 11, 1.5)
sr1.plot.line(style='bo--', grid=True, yticks=ytk)

plt.subplot(2,2,2)
data2 = np.random.randint(10, 101, 20)
sr2 = pd.Series(data2)
sr2[sr2 > 50].head(5).plot(kind='bar', rot=0,
                           use_index=False, 
                           fontsize=14, 
                           xticks=np.arange(0, 100, 15))

plt.subplot(2,2,3)
data3 = np.random.randint(10, 101, 5)
sr3 = pd.Series(data3)
sr3.plot(kind='barh', rot=0,
         use_index=False, fontsize=14, 
         xticks=np.arange(0, 100, 20))

plt.subplots_adjust(wspace=0.5, hspace=0.5)

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')

data = [[10, 20, 40, 30, 30],
        [40, 20, 5, 25, 15],
        [25, 30, 25, 40, 20]]

df = pd.DataFrame(data, 
                  columns=['one', 'two', 'three', 'four', 'five'],
                  index=list('abc'))
display(df)

df.plot.line(fontsize=14)
# Out:
#    one  two  three  four  five
# a   10   20     40    30    30
# b   40   20      5    25    15
# c   25   30     25    40    20

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')

data = {'one': [10, 20, 40, 30, 30],
        'two': [40, 20, 5, 25, 15],
        'three': [25, 30, 25, 40, 20]}

df = pd.DataFrame(data, index=list('abcde'))

display(df)
df.plot(kind='line', fontsize=14)
# Out:
#    one  two  three
# a   10   40     25
# b   20   20     30
# c   40    5     25
# d   30   25     40
# e   30   15     20

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')
plt.rcParams['font.sans-serif'] = 'tahoma'
plt.rcParams['font.family'] = 'tahoma'
plt.rcParams['font.size'] = 14

data = {'สินค้า 1': [10, 20, 40, 30, 30],
        'สินค้า 2': [40, 20, 5, 25, 15],
        'สินค้า 3': [25, 30, 25, 40, 20] }

idx = ['จันทร์', 'อังคาร', 'พุธ', 'พฤหัส', 'ศุกร์']
df = pd.DataFrame(data, index=idx)

df.plot(kind='line', 
        style=['ro-', 'gD:', 'bs--'],
        use_index=True, legend=True, 
        rot=45, fontsize=14)

plt.title('ยอดขายสินค้าระหว่างวันจันทร์ - ศุกร์', fontsize=16, c='g')
plt.xlabel('วัน', fontsize=16, c='m')
plt.ylabel('ยอดขาย', fontsize=16, c='m')
# Out:
# Text(0, 0.5, 'ยอดขาย')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn')

data = {'one': np.random.randint(10, 101, 5),
        'two': np.random.randint(10, 101, 5),
        'three': np.random.randint(10, 101, 5),
        'four': np.random.randint(10, 101, 5),
        'five': np.random.randint(10, 101, 5)}

df = pd.DataFrame(data, index=list('ABCDE'))

df[['two', 'four']].head(3).plot.line(fontsize=14, 
                                      style=['ro--', 'cs:'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')
plt.rcParams['font.sans-serif'] = 'tahoma'
plt.rcParams['font.family'] = 'tahoma'
plt.rcParams['font.size'] = 14

data = {'สินค้า 1': [10, 20, 40, 30, 30],
        'สินค้า 2': [40, 20, 5, 25, 15],
        'สินค้า 3': [25, 30, 25, 40, 20]}

idx = ['จันทร์', 'อังคาร', 'พุธ', 'พฤหัส', 'ศุกร์']

df = pd.DataFrame(data, index=idx)

df.plot(kind='bar', rot=0, fontsize=14, legend=True, 
        color=['green', 'lightblue', 'blue'])

plt.title('ยอดขายสินค้าระหว่างวันจันทร์ - ศุกร์', fontsize=16, c='g')
plt.xlabel('วัน', fontsize=16, c='m')
plt.ylabel('ยอดขาย', fontsize=16, c='m')
# Out:
# Text(0, 0.5, 'ยอดขาย')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn')

data = {'one': np.random.randint(10, 101, 5),
        'two': np.random.randint(10, 101, 5),
        'three': np.random.randint(10, 101, 5)}

df = pd.DataFrame(data, index=list('ABCDE'))

df.plot.barh(fontsize=14, width=0.7, grid=True, 
             use_index=True, color=['b', 'lightblue', 'm'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = {'one': np.random.randint(10, 101, 5),
        'two': np.random.randint(10, 101, 5),
        'three': np.random.randint(10, 101, 5)}

df = pd.DataFrame(data, index=list('ABCDE'))

exp = [0, 0.2, 0, 0, 0.2]
df['two'].plot.pie(fontsize=14, autopct='%.1f%%', 
                   startangle=45, shadow=False,
                   explode=exp, 
                   colors=['lightgreen', 'lightcyan', 'pink', 
                           'lightblue', 'wheat'])

plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def rand():
    return np.random.randint(10, 16, 20)

plt.style.use('seaborn')

data = {'one': rand(),
        'two': rand(),
        'three': rand()}

df = pd.DataFrame(data, index=np.arange(0, 20))

df['two'].plot.hist(bins=5, color=['c', 'm'], 
                    edgecolor='w', fontsize=14)

plt.xticks(np.arange(10, 16))
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')

data = {'one': [10, 20, 40, 30, 30],
        'two': [40, 20, 5, 25, 15],
        'three': [25, 30, 25, 40, 20]}

df = pd.DataFrame(data, index=list('abcde')) 
df.plot(kind='line', rot=0,
        fontsize=14, subplots=True)   # *****
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000219881918D0>,
# ...
#       dtype=object)

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')

plt.rcParams['font.sans-serif'] = 'tahoma'
plt.rcParams['font.family'] = 'tahoma'
plt.rcParams['font.size'] = 14

data = {'สินค้า 1': [10, 20, 40, 30, 30],
        'สินค้า 2': [40, 20, 5, 25, 15],
        'สินค้า 3': [25, 30, 25, 40, 20] }

idx = ['จันทร์', 'อังคาร', 'พุธ', 'พฤหัส', 'ศุกร์']

df = pd.DataFrame(data, index=idx)

df.plot(kind='bar', rot=0, 
        fontsize=14, legend=False, 
        subplots=True,   # *****
        title='ยอดขายสินค้าระหว่างวันจันทร์ - ศุกร์')

plt.xlabel('วัน', fontsize=16, c='m')
plt.ylabel('ยอดขาย', fontsize=16, c='m')

plt.subplots_adjust(hspace=0.5)

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')

data = {'one': [30, 20, 10, 15, 25],
        'two': [40, 10, 20, 15, 15],
        'three': [15, 15, 10, 40, 20],
        'four': [15, 20, 30, 25, 10]}

df = pd.DataFrame(data, index=list('ABCDE'))

exp = [0, 0.2, 0, 0, 0.3]

c = ['lightgreen', 'cyan', 'pink', 'lightblue', 'wheat']

plt.subplot(2, 2, 1)
df['one'].plot.pie(fontsize=14, autopct='%1.1f%%', explode=exp, 
                   colors=c)

plt.subplot(2, 2, 2)
df['two'].plot.pie(fontsize=14, autopct='%1.1f%%', explode=exp, 
                   colors=c)

plt.subplot(2, 2, 3)
df['three'].plot.pie(fontsize=14, autopct='%1.1f%%', explode=exp, 
                     colors=c)

plt.subplot(2, 2, 4)
df['four'].plot.pie(fontsize=14, autopct='%1.1f%%', explode=exp, 
                    colors=c)

plt.subplots_adjust(wspace=0.5, hspace=0.4)

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')

data = {'group': ['B', 'C', 'B', 'A', 'A', 'C', 'B', 'C', 'A'],
        'name': ['Jim', 'John', 'Jack', 'Jane', 'Joe', 'Jake', 
                 'Jeff', 'Jill', 'James'],
        'score': [70, 60, 80, 50, 70, 50, 90, 70, 80]}

df = pd.DataFrame(data)

df.groupby('group').sum().plot(kind='bar', rot=0, color='c')

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')

data = {'group': ['B', 'C', 'B', 'A', 'A', 'C', 'B', 'C', 'A', 'B'],
        'gender': ['Male', 'Male', 'Male', 'Female', 'Male', 
                   'Female', 'Male', 'Female', 'Male', 'Female'],
        'name': ['Jim', 'John', 'Jack', 'Jane', 'Joe', 'Joy', 
                 'Jeff', 'Jill', 'James', 'Jan'],
        'score': [70, 60, 80, 50, 70, 50, 90, 70, 80, 90]}

df = pd.DataFrame(data)
#display(df.sort_values('gender'))

pv = df.pivot_table(index='group',
                    columns='gender', 
                    values='score',
                    aggfunc='sum').add_suffix('_sum')

display(pv)

pv.plot(style=['ro:', 'go--'])
# Out:
# gender  Female_sum  Male_sum
# group
# A               50       150
# B               90       240
# C              120        60

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

idx = pd.date_range('2020-01', periods=12, freq='MS')   

sr1 = pd.Series(np.random.randint(10, 100, len(idx)), index=idx)
sr2 = pd.Series(np.random.randint(10, 100, len(idx)), index=idx)

sr1.plot.line(style='-', label='sr1', legend=True)
sr2.plot.line(style='--', label='sr2', legend=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

idx = pd.period_range('2020Q1', periods=8, freq='Q')   
sr1 = pd.Series(np.random.randint(10, 100, len(idx)), index=idx)
sr2 = pd.Series(np.random.randint(10, 100, len(idx)), index=idx)
sr3 = pd.Series(np.random.randint(10, 100, len(idx)), index=idx)
sr4 = pd.Series(np.random.randint(10, 100, len(idx)), index=idx)

sr1.plot.line(style='ro-', label='Product 1', legend=True)
sr2.plot.line(style='gs--', label='Product 2', legend=True)
sr3.plot.line(style='bD:', label='Product 3', legend=True)
sr4.plot.line(style='yP-.', label='Product 2', legend=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn')

idx = pd.period_range('2020', periods=20, freq='A')
data = {'one': np.random.randint(10, 100, len(idx)),
        'two': np.random.randint(10, 100, len(idx)),
        'three': np.random.randint(10, 100, len(idx))}

df = pd.DataFrame(data, index=idx)
df['2020':'2029'].plot.bar(rot=0, color=['g', 'lightblue', 'b'])
