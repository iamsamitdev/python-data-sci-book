# %%
import pandas as pd

df = pd.read_csv('data-sci\\NCHS1.csv')

display(df.head(5),
        df.tail(5))
# Out:
#    Year                                     113 Cause Name  \
# 0  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2017  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name          State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries  United States  169936                     49.4
# 1  Unintentional injuries        Alabama    2703                     53.8
# 2  Unintentional injuries         Alaska     436                     63.7
# 3  Unintentional injuries        Arizona    4184                     56.2
# 4  Unintentional injuries       Arkansas    1625                     51.8
#        Year                                     113 Cause Name  \
# 10863  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10864  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10865  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10866  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10867  1999  Nephritis, nephrotic syndrome and nephrosis (N...
#
#            Cause Name          State  Deaths  Age-adjusted Death Rate
# 10863  Kidney disease       Virginia    1035                     16.9
# 10864  Kidney disease     Washington     278                      5.2
# 10865  Kidney disease  West Virginia     345                     16.4
# 10866  Kidney disease      Wisconsin     677                     11.9
# 10867  Kidney disease        Wyoming      30                      6.8

# %%
import pandas as pd

df = pd.read_csv('data-sci\\NCHS1.csv')

print(df['Cause Name'].unique(),
      df['State'].unique(),
      sep='\n\n')
# Out:
# ['Unintentional injuries' 'All causes' "Alzheimer's disease" 'Stroke'
#  'CLRD' 'Diabetes' 'Heart disease' 'Influenza and pneumonia' 'Suicide'
#  'Cancer' 'Kidney disease']
#
# ['United States' 'Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California'
#  'Colorado' 'Connecticut' 'Delaware' 'District of Columbia' 'Florida'
#  'Georgia' 'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas'
#  'Kentucky' 'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan'
#  'Minnesota' 'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada'
#  'New Hampshire' 'New Jersey' 'New Mexico' 'New York' 'North Carolina'
#  'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island'
#  'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont'
#  'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']

# %%
import pandas as pd

df = pd.read_csv('data-sci\\NCHS1.csv')
print('Old file', df.shape)

df2 = df[df['Cause Name'] != 'All causes']
df3 = df2[df2['State'] != 'United States']

df3.to_csv('data-sci\\NCHS2.csv', index=None)
print('New file', df3.shape)
# Out:
# Old file (10868, 6)
# New file (9690, 6)

# %%
import pandas as pd

df = pd.read_csv('data-sci\\NCHS2.csv')

print(df['Cause Name'].unique(), 
      df['State'].unique(), 
      sep='\n\n')
# Out:
# ['Unintentional injuries' "Alzheimer's disease" 'Stroke' 'CLRD' 'Diabetes'
#  'Heart disease' 'Influenza and pneumonia' 'Suicide' 'Cancer'
#  'Kidney disease']
#
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'District of Columbia' 'Florida' 'Georgia'
#  'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky'
#  'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan' 'Minnesota'
#  'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire'
#  'New Jersey' 'New Mexico' 'New York' 'North Carolina' 'North Dakota'
#  'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia'
#  'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']

# %%
import pandas as pd

df = pd.read_csv('data-sci\\NCHS2.csv')

sum = df['Deaths'].sum()
sum_fm = format(sum, ',')

print('Total deaths:', sum_fm)
# Out:
# Total deaths: 36,280,583

# %%
import pandas as pd

df = pd.read_csv('data-sci\\NCHS2.csv')

df_ca = df[(df.Year == 2017) & (df.State == 'California')]

df_ca
# Out:
#      Year                                     113 Cause Name  \
# 4    2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 55   2017                          Alzheimer's disease (G30)
# 106  2017                 Cerebrovascular diseases (I60-I69)
# 157  2017       Chronic lower respiratory diseases (J40-J47)
# 208  2017                        Diabetes mellitus (E10-E14)
# 259  2017        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 310  2017                  Influenza and pneumonia (J09-J18)
# 361  2017  Intentional self-harm (suicide) (*U03,X60-X84,...
# 412  2017                      Malignant neoplasms (C00-C97)
# 463  2017  Nephritis, nephrotic syndrome and nephrosis (N...
#
#                   Cause Name       State  Deaths  Age-adjusted Death Rate
# 4     Unintentional injuries  California   13840                     33.2
# 55       Alzheimer's disease  California   16238                     37.1
# 106                   Stroke  California   16355                     37.6
# 157                     CLRD  California   13881                     32.2
# 208                 Diabetes  California    9595                     22.1
# 259            Heart disease  California   62797                    142.9
# 310  Influenza and pneumonia  California    6340                     14.6
# 361                  Suicide  California    4312                     10.5
# 412                   Cancer  California   59516                    136.8
# 463           Kidney disease  California    3887                      8.9

# %%
import pandas as pd

df = pd.read_csv('data-sci\\NCHS2.csv')

df_diabetes = df[df['Cause Name'] == 'Diabetes']
sum_diabetes = df_diabetes['Deaths'].sum()

#หรือเขียนรวมในขั้นตอนเดียวเป็น
#sum_diabetes_sum = df[df['Cause Name'] == 'Diabetes']['Deaths'].sum()

print('Total deaths of diabetes :', format(sum_diabetes, ','))

suicide_2015_2017 = df[(df['Cause Name'] == 'Suicide') &
                       (df['Year'] >= 2015) & (df['Year'] <= 2017)]

sum_suicide = suicide_2015_2017['Deaths'].sum()

print('Total deaths of suicide between 2015-2017 :', 
      format(sum_suicide, ','))
# Out:
# Total deaths of diabetes : 1,399,943
# Total deaths of suicide between 2015-2017 : 136,331

# %%
import pandas as pd

df = pd.read_csv('data-sci\\NCHS2.csv')

df = df[df.Year >= 2010].groupby('Year').sum()

df[['Deaths']].style.format('{:,}')
# Out:
# <style  type="text/css" >
# </style><table id="T_20f3f9c6_4003_11ea_8797_abae71f60986" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Deaths</th>    </tr>    <tr>        <th class="index_name level0" >Year</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_20f3f9c6_4003_11ea_8797_abae71f60986level0_row0" class="row_heading level0 row0" >2010</th>
#                         <td id="T_20f3f9c6_4003_11ea_8797_abae71f60986row0_col0" class="data row0 col0" >1,852,349</td>
#             </tr>
#             <tr>
#                         <th id="T_20f3f9c6_4003_11ea_8797_abae71f60986level0_row1" class="row_heading level0 row1" >2011</th>
#                         <td id="T_20f3f9c6_4003_11ea_8797_abae71f60986row1_col0" class="data row1 col0" >1,869,321</td>
#             </tr>
#             <tr>
#                         <th id="T_20f3f9c6_4003_11ea_8797_abae71f60986level0_row2" class="row_heading level0 row2" >2012</th>
#                         <td id="T_20f3f9c6_4003_11ea_8797_abae71f60986row2_col0" class="data row2 col0" >1,876,588</td>
#             </tr>
#             <tr>
#                         <th id="T_20f3f9c6_4003_11ea_8797_abae71f60986level0_row3" class="row_heading level0 row3" >2013</th>
#                         <td id="T_20f3f9c6_4003_11ea_8797_abae71f60986row3_col0" class="data row3 col0" >1,910,311</td>
#             </tr>
#             <tr>
#                         <th id="T_20f3f9c6_4003_11ea_8797_abae71f60986level0_row4" class="row_heading level0 row4" >2014</th>
#                         <td id="T_20f3f9c6_4003_11ea_8797_abae71f60986row4_col0" class="data row4 col0" >1,938,408</td>
#             </tr>
#             <tr>
#                         <th id="T_20f3f9c6_4003_11ea_8797_abae71f60986level0_row5" class="row_heading level0 row5" >2015</th>
#                         <td id="T_20f3f9c6_4003_11ea_8797_abae71f60986row5_col0" class="data row5 col0" >2,013,017</td>
#             </tr>
#             <tr>
#                         <th id="T_20f3f9c6_4003_11ea_8797_abae71f60986level0_row6" class="row_heading level0 row6" >2016</th>
#                         <td id="T_20f3f9c6_4003_11ea_8797_abae71f60986row6_col0" class="data row6 col0" >2,034,119</td>
#             </tr>
#             <tr>
#                         <th id="T_20f3f9c6_4003_11ea_8797_abae71f60986level0_row7" class="row_heading level0 row7" >2017</th>
#                         <td id="T_20f3f9c6_4003_11ea_8797_abae71f60986row7_col0" class="data row7 col0" >2,081,531</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('data-sci\\NCHS2.csv')

df = df.groupby('State').sum().sort_values(by='Deaths', ascending=False)

df[['Deaths']].head(10).style.format('{:,}')
# Out:
# <style  type="text/css" >
# </style><table id="T_d9570354_4045_11ea_803b_abae71f60986" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Deaths</th>    </tr>    <tr>        <th class="index_name level0" >State</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d9570354_4045_11ea_803b_abae71f60986level0_row0" class="row_heading level0 row0" >California</th>
#                         <td id="T_d9570354_4045_11ea_803b_abae71f60986row0_col0" class="data row0 col0" >3,594,261</td>
#             </tr>
#             <tr>
#                         <th id="T_d9570354_4045_11ea_803b_abae71f60986level0_row1" class="row_heading level0 row1" >Florida</th>
#                         <td id="T_d9570354_4045_11ea_803b_abae71f60986row1_col0" class="data row1 col0" >2,533,472</td>
#             </tr>
#             <tr>
#                         <th id="T_d9570354_4045_11ea_803b_abae71f60986level0_row2" class="row_heading level0 row2" >Texas</th>
#                         <td id="T_d9570354_4045_11ea_803b_abae71f60986row2_col0" class="data row2 col0" >2,367,695</td>
#             </tr>
#             <tr>
#                         <th id="T_d9570354_4045_11ea_803b_abae71f60986level0_row3" class="row_heading level0 row3" >New York</th>
#                         <td id="T_d9570354_4045_11ea_803b_abae71f60986row3_col0" class="data row3 col0" >2,264,120</td>
#             </tr>
#             <tr>
#                         <th id="T_d9570354_4045_11ea_803b_abae71f60986level0_row4" class="row_heading level0 row4" >Pennsylvania</th>
#                         <td id="T_d9570354_4045_11ea_803b_abae71f60986row4_col0" class="data row4 col0" >1,854,953</td>
#             </tr>
#             <tr>
#                         <th id="T_d9570354_4045_11ea_803b_abae71f60986level0_row5" class="row_heading level0 row5" >Ohio</th>
#                         <td id="T_d9570354_4045_11ea_803b_abae71f60986row5_col0" class="data row5 col0" >1,605,250</td>
#             </tr>
#             <tr>
#                         <th id="T_d9570354_4045_11ea_803b_abae71f60986level0_row6" class="row_heading level0 row6" >Illinois</th>
#                         <td id="T_d9570354_4045_11ea_803b_abae71f60986row6_col0" class="data row6 col0" >1,508,039</td>
#             </tr>
#             <tr>
#                         <th id="T_d9570354_4045_11ea_803b_abae71f60986level0_row7" class="row_heading level0 row7" >Michigan</th>
#                         <td id="T_d9570354_4045_11ea_803b_abae71f60986row7_col0" class="data row7 col0" >1,313,813</td>
#             </tr>
#             <tr>
#                         <th id="T_d9570354_4045_11ea_803b_abae71f60986level0_row8" class="row_heading level0 row8" >North Carolina</th>
#                         <td id="T_d9570354_4045_11ea_803b_abae71f60986row8_col0" class="data row8 col0" >1,115,953</td>
#             </tr>
#             <tr>
#                         <th id="T_d9570354_4045_11ea_803b_abae71f60986level0_row9" class="row_heading level0 row9" >New Jersey</th>
#                         <td id="T_d9570354_4045_11ea_803b_abae71f60986row9_col0" class="data row9 col0" >1,030,622</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('data-sci\\NCHS2.csv')

df = df.groupby(['Cause Name']).sum().sort_values(by='Deaths', 
                                                  ascending=False)

df[['Deaths']].style.format('{:,}')
# Out:
# <style  type="text/css" >
# </style><table id="T_1c472466_4003_11ea_aebb_abae71f60986" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Deaths</th>    </tr>    <tr>        <th class="index_name level0" >Cause Name</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1c472466_4003_11ea_aebb_abae71f60986level0_row0" class="row_heading level0 row0" >Heart disease</th>
#                         <td id="T_1c472466_4003_11ea_aebb_abae71f60986row0_col0" class="data row0 col0" >12,222,640</td>
#             </tr>
#             <tr>
#                         <th id="T_1c472466_4003_11ea_aebb_abae71f60986level0_row1" class="row_heading level0 row1" >Cancer</th>
#                         <td id="T_1c472466_4003_11ea_aebb_abae71f60986row1_col0" class="data row1 col0" >10,843,644</td>
#             </tr>
#             <tr>
#                         <th id="T_1c472466_4003_11ea_aebb_abae71f60986level0_row2" class="row_heading level0 row2" >Stroke</th>
#                         <td id="T_1c472466_4003_11ea_aebb_abae71f60986row2_col0" class="data row2 col0" >2,726,523</td>
#             </tr>
#             <tr>
#                         <th id="T_1c472466_4003_11ea_aebb_abae71f60986level0_row3" class="row_heading level0 row3" >CLRD</th>
#                         <td id="T_1c472466_4003_11ea_aebb_abae71f60986row3_col0" class="data row3 col0" >2,594,927</td>
#             </tr>
#             <tr>
#                         <th id="T_1c472466_4003_11ea_aebb_abae71f60986level0_row4" class="row_heading level0 row4" >Unintentional injuries</th>
#                         <td id="T_1c472466_4003_11ea_aebb_abae71f60986row4_col0" class="data row4 col0" >2,347,820</td>
#             </tr>
#             <tr>
#                         <th id="T_1c472466_4003_11ea_aebb_abae71f60986level0_row5" class="row_heading level0 row5" >Alzheimer's disease</th>
#                         <td id="T_1c472466_4003_11ea_aebb_abae71f60986row5_col0" class="data row5 col0" >1,494,816</td>
#             </tr>
#             <tr>
#                         <th id="T_1c472466_4003_11ea_aebb_abae71f60986level0_row6" class="row_heading level0 row6" >Diabetes</th>
#                         <td id="T_1c472466_4003_11ea_aebb_abae71f60986row6_col0" class="data row6 col0" >1,399,943</td>
#             </tr>
#             <tr>
#                         <th id="T_1c472466_4003_11ea_aebb_abae71f60986level0_row7" class="row_heading level0 row7" >Influenza and pneumonia</th>
#                         <td id="T_1c472466_4003_11ea_aebb_abae71f60986row7_col0" class="data row7 col0" >1,094,641</td>
#             </tr>
#             <tr>
#                         <th id="T_1c472466_4003_11ea_aebb_abae71f60986level0_row8" class="row_heading level0 row8" >Kidney disease</th>
#                         <td id="T_1c472466_4003_11ea_aebb_abae71f60986row8_col0" class="data row8 col0" >858,613</td>
#             </tr>
#             <tr>
#                         <th id="T_1c472466_4003_11ea_aebb_abae71f60986level0_row9" class="row_heading level0 row9" >Suicide</th>
#                         <td id="T_1c472466_4003_11ea_aebb_abae71f60986row9_col0" class="data row9 col0" >697,016</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('data-sci\\NCHS2.csv')

#กำหนดเงื่อนไขโดยเลือกเฉพาะข้อมูลของรัฐ Florida ตั้งแต่ปี 2015 เป็นต้นมา
df_fl = df[(df.Year >= 2015) & (df.State == 'Florida')]

#เรียงลำดับข้อมูลจากมากไปหาน้อย
df_fl = df_fl.sort_values(by='Deaths', ascending=False)

#แบ่งกลุ่มตามปีค.ศ. แล้วเลือกข้อมูล 3 ลำดับแรกของแต่ละกลุ่ม
df_fl = df_fl.groupby(['Year']).head(3)

#display(df_fl)

#จัดกลุ่มอีกครั้ง โดยใช้ปีและสาเหตุการเสียชีวิตในการจัดกลุ่ม
#แล้วแสดงผลรวมของแต่ละกลุ่ม ในแบบ Aggregate Function 
#เพื่อหาผลรวมเฉพาะคอลัมน์ Deaths 
g = df_fl.groupby(['Year', 'Cause Name']).agg({'Deaths':sum})

#หรือแบบนี้ก็ได้
#g = df_fl.groupby(['Year', 'Cause Name'])[['Deaths']].sum()

g.style.format('{:,}')
# Out:
# <style  type="text/css" >
# </style><table id="T_97956a7a_4244_11ea_bbc6_abae71f60986" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Deaths</th>    </tr>    <tr>        <th class="index_name level0" >Year</th>        <th class="index_name level1" >Cause Name</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_97956a7a_4244_11ea_bbc6_abae71f60986level0_row0" class="row_heading level0 row0" rowspan=3>2015</th>
#                         <th id="T_97956a7a_4244_11ea_bbc6_abae71f60986level1_row0" class="row_heading level1 row0" >CLRD</th>
#                         <td id="T_97956a7a_4244_11ea_bbc6_abae71f60986row0_col0" class="data row0 col0" >11,705</td>
#             </tr>
#             <tr>
#                                 <th id="T_97956a7a_4244_11ea_bbc6_abae71f60986level1_row1" class="row_heading level1 row1" >Cancer</th>
#                         <td id="T_97956a7a_4244_11ea_bbc6_abae71f60986row1_col0" class="data row1 col0" >44,027</td>
#             </tr>
#             <tr>
#                                 <th id="T_97956a7a_4244_11ea_bbc6_abae71f60986level1_row2" class="row_heading level1 row2" >Heart disease</th>
#                         <td id="T_97956a7a_4244_11ea_bbc6_abae71f60986row2_col0" class="data row2 col0" >45,441</td>
#             </tr>
#             <tr>
#                         <th id="T_97956a7a_4244_11ea_bbc6_abae71f60986level0_row3" class="row_heading level0 row3" rowspan=3>2016</th>
#                         <th id="T_97956a7a_4244_11ea_bbc6_abae71f60986level1_row3" class="row_heading level1 row3" >Cancer</th>
#                         <td id="T_97956a7a_4244_11ea_bbc6_abae71f60986row3_col0" class="data row3 col0" >44,266</td>
#             </tr>
#             <tr>
#                                 <th id="T_97956a7a_4244_11ea_bbc6_abae71f60986level1_row4" class="row_heading level1 row4" >Heart disease</th>
#                         <td id="T_97956a7a_4244_11ea_bbc6_abae71f60986row4_col0" class="data row4 col0" >45,659</td>
#             </tr>
#             <tr>
#                                 <th id="T_97956a7a_4244_11ea_bbc6_abae71f60986level1_row5" class="row_heading level1 row5" >Unintentional injuries</th>
#                         <td id="T_97956a7a_4244_11ea_bbc6_abae71f60986row5_col0" class="data row5 col0" >12,561</td>
#             </tr>
#             <tr>
#                         <th id="T_97956a7a_4244_11ea_bbc6_abae71f60986level0_row6" class="row_heading level0 row6" rowspan=3>2017</th>
#                         <th id="T_97956a7a_4244_11ea_bbc6_abae71f60986level1_row6" class="row_heading level1 row6" >Cancer</th>
#                         <td id="T_97956a7a_4244_11ea_bbc6_abae71f60986row6_col0" class="data row6 col0" >45,131</td>
#             </tr>
#             <tr>
#                                 <th id="T_97956a7a_4244_11ea_bbc6_abae71f60986level1_row7" class="row_heading level1 row7" >Heart disease</th>
#                         <td id="T_97956a7a_4244_11ea_bbc6_abae71f60986row7_col0" class="data row7 col0" >46,440</td>
#             </tr>
#             <tr>
#                                 <th id="T_97956a7a_4244_11ea_bbc6_abae71f60986level1_row8" class="row_heading level1 row8" >Unintentional injuries</th>
#                         <td id="T_97956a7a_4244_11ea_bbc6_abae71f60986row8_col0" class="data row8 col0" >13,059</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')

df = pd.read_csv('data-sci\\NCHS2.csv')
df = df[df.Year >= 2010].groupby('Year').sum()

plt.plot(df.index, df['Deaths'], 'ro-')
plt.show()

#df[['Deaths']].plot(kind='line', style='ro-')

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')

df = pd.read_csv('data-sci\\NCHS2.csv')

df = df[(df.Year >= 2008) & (df['Cause Name'] == 'Kidney disease')]
df = df.groupby('Year').sum()

plt.plot(df.index, df['Deaths'], 'mD-')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')
plt.rcParams['font.sans-serif'] = 'tahoma'
plt.rcParams['font.family'] = 'tahoma'
plt.rcParams['font.size'] = 14

df = pd.read_csv('data-sci\\NCHS2.csv')

df = df[df.State == 'California'].groupby('Cause Name').sum()

#display(df)

df[['Deaths']].plot.bar(color='y')

# %%
import pandas as pd

df = pd.read_csv('data-sci\\countries_info.csv')

display(df.head(5),
        df.tail(5))
# Out:
#           Country                Region  Population  Area_sq_mi  \
# 0     Afghanistan  ASIA (EX. NEAR EAST)    31056997      647500
# 1         Albania        EASTERN EUROPE     3581655       28748
# 2         Algeria       NORTHERN AFRICA    32930091     2381740
# 3  American Samoa               OCEANIA       57794         199
# 4         Andorra        WESTERN EUROPE       71201         468
#
#    GDP_USD_per_capita
# 0               700.0
# 1              4500.0
# 2              6000.0
# 3              8000.0
# 4             19000.0
#             Country              Region  Population  Area_sq_mi  \
# 222       West Bank           NEAR EAST     2460492        5860
# 223  Western Sahara     NORTHERN AFRICA      273008      266000
# 224           Yemen           NEAR EAST    21456188      527970
# 225          Zambia  SUB-SAHARAN AFRICA    11502010      752614
# 226        Zimbabwe  SUB-SAHARAN AFRICA    12236805      390580
#
#      GDP_USD_per_capita
# 222               800.0
# 223                 NaN
# 224               800.0
# 225               800.0
# 226              1900.0

# %%
import pandas as pd

df = pd.read_csv('data-sci\\countries_info.csv')

th = df[df['Country'] == 'Thailand']

th.style.format('{:,}', subset=pd.IndexSlice[:, 'Population':])
# Out:
# <style  type="text/css" >
# </style><table id="T_c9b33a4c_4196_11ea_aa07_abae71f60986" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country</th>        <th class="col_heading level0 col1" >Region</th>        <th class="col_heading level0 col2" >Population</th>        <th class="col_heading level0 col3" >Area_sq_mi</th>        <th class="col_heading level0 col4" >GDP_USD_per_capita</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c9b33a4c_4196_11ea_aa07_abae71f60986level0_row0" class="row_heading level0 row0" >201</th>
#                         <td id="T_c9b33a4c_4196_11ea_aa07_abae71f60986row0_col0" class="data row0 col0" >Thailand</td>
#                         <td id="T_c9b33a4c_4196_11ea_aa07_abae71f60986row0_col1" class="data row0 col1" >ASIA (EX. NEAR EAST)</td>
#                         <td id="T_c9b33a4c_4196_11ea_aa07_abae71f60986row0_col2" class="data row0 col2" >64,631,595</td>
#                         <td id="T_c9b33a4c_4196_11ea_aa07_abae71f60986row0_col3" class="data row0 col3" >514,000</td>
#                         <td id="T_c9b33a4c_4196_11ea_aa07_abae71f60986row0_col4" class="data row0 col4" >7,400.0</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('data-sci\\countries_info.csv')

print(df.Region.unique())
# Out:
# ['ASIA (EX. NEAR EAST)' 'EASTERN EUROPE' 'NORTHERN AFRICA' 'OCEANIA'
#  'WESTERN EUROPE' 'SUB-SAHARAN AFRICA' 'LATIN AMER. & CARIB'
#  'C.W. OF IND. STATES' 'NEAR EAST' 'NORTHERN AMERICA' 'BALTICS']

# %%
import pandas as pd

df = pd.read_csv('data-sci\\countries_info.csv')

display(df[df['Region'].str.startswith('ASIA')].head(3),
        df[df['Region'].str.endswith('AMERICA')].head(3),
        df[df['Region'].str.find('EUROPE') != -1].head(3))
# Out:
#         Country                Region  Population  Area_sq_mi  \
# 0   Afghanistan  ASIA (EX. NEAR EAST)    31056997      647500
# 16   Bangladesh  ASIA (EX. NEAR EAST)   147365352      144000
# 23       Bhutan  ASIA (EX. NEAR EAST)     2279723       47000
#
#     GDP_USD_per_capita
# 0                700.0
# 16              1900.0
# 23              1300.0
#       Country            Region  Population  Area_sq_mi  GDP_USD_per_capita
# 22    Bermuda  NORTHERN AMERICA       65773          53             36000.0
# 36     Canada  NORTHERN AMERICA    33098932     9984670             29800.0
# 80  Greenland  NORTHERN AMERICA       56361     2166086             20000.0
#     Country          Region  Population  Area_sq_mi  GDP_USD_per_capita
# 1   Albania  EASTERN EUROPE     3581655       28748              4500.0
# 4   Andorra  WESTERN EUROPE       71201         468             19000.0
# 12  Austria  WESTERN EUROPE     8192880       83870             30000.0

# %%
import pandas as pd

df = pd.read_csv('data-sci\\countries_info.csv')

idx_max = df['Population'].idxmax()

sr_pop = df.loc[idx_max]

#แนวทางการแสดงผลแบบต่างๆ
display(sr_pop,
        sr_pop.to_frame(),
        sr_pop.to_frame().T)  #หรือใช้ transpose() แทน T
# Out:
# Country                              China
# Region                ASIA (EX. NEAR EAST)
# Population                      1313973713
# Area_sq_mi                         9596960
# GDP_USD_per_capita                    5000
# Name: 42, dtype: object
#                                       42
# Country                            China
# Region              ASIA (EX. NEAR EAST)
# Population                    1313973713
# Area_sq_mi                       9596960
# GDP_USD_per_capita                  5000
#    Country                Region  Population Area_sq_mi GDP_USD_per_capita
# 42   China  ASIA (EX. NEAR EAST)  1313973713    9596960               5000

# %%
import pandas as pd

df = pd.read_csv('data-sci\\countries_info.csv')

idx_max = df['GDP_USD_per_capita'].idxmax()

sr_gdp = df.loc[idx_max]

display(sr_gdp.to_frame(),
        sr_gdp.to_frame().T)
# Out:
#                                121
# Country                 Luxembourg
# Region              WESTERN EUROPE
# Population                  474413
# Area_sq_mi                    2586
# GDP_USD_per_capita           55100
#         Country          Region Population Area_sq_mi GDP_USD_per_capita
# 121  Luxembourg  WESTERN EUROPE     474413       2586              55100

# %%
import pandas as pd

df = pd.read_csv('data-sci\\countries_info.csv')

df_sorted_gdp = df.sort_values(by='GDP_USD_per_capita', ascending=False)

df_sorted_gdp.reset_index(inplace=True)

df_h10 = df_sorted_gdp.head(10)

display(df_h10.style.format('{:,.0f}', 
                            subset=pd.IndexSlice[:, 'Population':]))

#ลำดับของประเทศไทย
th_idx = df_sorted_gdp[df_sorted_gdp['Country'] == 'Thailand'].index

print('Thailand rank:', th_idx[0] + 1)
# Out:
# <style  type="text/css" >
# </style><table id="T_1bd37fb6_4195_11ea_bba4_abae71f60986" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Country</th>        <th class="col_heading level0 col2" >Region</th>        <th class="col_heading level0 col3" >Population</th>        <th class="col_heading level0 col4" >Area_sq_mi</th>        <th class="col_heading level0 col5" >GDP_USD_per_capita</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1bd37fb6_4195_11ea_bba4_abae71f60986level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row0_col0" class="data row0 col0" >121</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row0_col1" class="data row0 col1" >Luxembourg</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row0_col2" class="data row0 col2" >WESTERN EUROPE</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row0_col3" class="data row0 col3" >474,413</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row0_col4" class="data row0 col4" >2,586</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row0_col5" class="data row0 col5" >55,100</td>
#             </tr>
#             <tr>
#                         <th id="T_1bd37fb6_4195_11ea_bba4_abae71f60986level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row1_col0" class="data row1 col0" >154</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row1_col1" class="data row1 col1" >Norway</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row1_col2" class="data row1 col2" >WESTERN EUROPE</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row1_col3" class="data row1 col3" >4,610,820</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row1_col4" class="data row1 col4" >323,802</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row1_col5" class="data row1 col5" >37,800</td>
#             </tr>
#             <tr>
#                         <th id="T_1bd37fb6_4195_11ea_bba4_abae71f60986level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row2_col0" class="data row2 col0" >214</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row2_col1" class="data row2 col1" >United States</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row2_col2" class="data row2 col2" >NORTHERN AMERICA</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row2_col3" class="data row2 col3" >298,444,215</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row2_col4" class="data row2 col4" >9,631,420</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row2_col5" class="data row2 col5" >37,800</td>
#             </tr>
#             <tr>
#                         <th id="T_1bd37fb6_4195_11ea_bba4_abae71f60986level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row3_col0" class="data row3 col0" >22</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row3_col1" class="data row3 col1" >Bermuda</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row3_col2" class="data row3 col2" >NORTHERN AMERICA</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row3_col3" class="data row3 col3" >65,773</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row3_col4" class="data row3 col4" >53</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row3_col5" class="data row3 col5" >36,000</td>
#             </tr>
#             <tr>
#                         <th id="T_1bd37fb6_4195_11ea_bba4_abae71f60986level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row4_col0" class="data row4 col0" >38</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row4_col1" class="data row4 col1" >Cayman Islands</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row4_col2" class="data row4 col2" >LATIN AMER. & CARIB</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row4_col3" class="data row4 col3" >45,436</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row4_col4" class="data row4 col4" >262</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row4_col5" class="data row4 col5" >35,000</td>
#             </tr>
#             <tr>
#                         <th id="T_1bd37fb6_4195_11ea_bba4_abae71f60986level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row5_col0" class="data row5 col0" >177</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row5_col1" class="data row5 col1" >San Marino</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row5_col2" class="data row5 col2" >WESTERN EUROPE</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row5_col3" class="data row5 col3" >29,251</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row5_col4" class="data row5 col4" >61</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row5_col5" class="data row5 col5" >34,600</td>
#             </tr>
#             <tr>
#                         <th id="T_1bd37fb6_4195_11ea_bba4_abae71f60986level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row6_col0" class="data row6 col0" >196</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row6_col1" class="data row6 col1" >Switzerland</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row6_col2" class="data row6 col2" >WESTERN EUROPE</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row6_col3" class="data row6 col3" >7,523,934</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row6_col4" class="data row6 col4" >41,290</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row6_col5" class="data row6 col5" >32,700</td>
#             </tr>
#             <tr>
#                         <th id="T_1bd37fb6_4195_11ea_bba4_abae71f60986level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row7_col0" class="data row7 col0" >54</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row7_col1" class="data row7 col1" >Denmark</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row7_col2" class="data row7 col2" >WESTERN EUROPE</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row7_col3" class="data row7 col3" >5,450,661</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row7_col4" class="data row7 col4" >43,094</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row7_col5" class="data row7 col5" >31,100</td>
#             </tr>
#             <tr>
#                         <th id="T_1bd37fb6_4195_11ea_bba4_abae71f60986level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row8_col0" class="data row8 col0" >93</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row8_col1" class="data row8 col1" >Iceland</td>
#                         <td id="T_1bd37fb6_4195_11ea_bba4_abae71f60986row8_col2" class="data row8 col2" >WESTERN EUROPE</td>
# Thailand rank: 94

# %%
import pandas as pd

df = pd.read_csv('data-sci\\countries_info.csv')

df = df.head(5)

df.insert(5, 'GDP_USD', df['Population'] * df['GDP_USD_per_capita'])     
df.insert(6, 'Pop_density_per_sq_mi', df['Population'] / df['Area_sq_mi'])

#display(df)

style = df.style.format('{:,.0f}', 
                        subset=pd.IndexSlice[:, 'Population':'GDP_USD'])

style.format({'Pop_density_per_sq_mi':'{:,.2f}'})

display(style)
# Out:
# <style  type="text/css" >
# </style><table id="T_90c592f4_41a6_11ea_865e_abae71f60986" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country</th>        <th class="col_heading level0 col1" >Region</th>        <th class="col_heading level0 col2" >Population</th>        <th class="col_heading level0 col3" >Area_sq_mi</th>        <th class="col_heading level0 col4" >GDP_USD_per_capita</th>        <th class="col_heading level0 col5" >GDP_USD</th>        <th class="col_heading level0 col6" >Pop_density_per_sq_mi</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_90c592f4_41a6_11ea_865e_abae71f60986level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row0_col0" class="data row0 col0" >Afghanistan</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row0_col1" class="data row0 col1" >ASIA (EX. NEAR EAST)</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row0_col2" class="data row0 col2" >31,056,997</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row0_col3" class="data row0 col3" >647,500</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row0_col4" class="data row0 col4" >700</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row0_col5" class="data row0 col5" >21,739,897,900</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row0_col6" class="data row0 col6" >47.96</td>
#             </tr>
#             <tr>
#                         <th id="T_90c592f4_41a6_11ea_865e_abae71f60986level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row1_col0" class="data row1 col0" >Albania</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row1_col1" class="data row1 col1" >EASTERN EUROPE</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row1_col2" class="data row1 col2" >3,581,655</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row1_col3" class="data row1 col3" >28,748</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row1_col4" class="data row1 col4" >4,500</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row1_col5" class="data row1 col5" >16,117,447,500</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row1_col6" class="data row1 col6" >124.59</td>
#             </tr>
#             <tr>
#                         <th id="T_90c592f4_41a6_11ea_865e_abae71f60986level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row2_col0" class="data row2 col0" >Algeria</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row2_col1" class="data row2 col1" >NORTHERN AFRICA</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row2_col2" class="data row2 col2" >32,930,091</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row2_col3" class="data row2 col3" >2,381,740</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row2_col4" class="data row2 col4" >6,000</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row2_col5" class="data row2 col5" >197,580,546,000</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row2_col6" class="data row2 col6" >13.83</td>
#             </tr>
#             <tr>
#                         <th id="T_90c592f4_41a6_11ea_865e_abae71f60986level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row3_col0" class="data row3 col0" >American Samoa</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row3_col1" class="data row3 col1" >OCEANIA</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row3_col2" class="data row3 col2" >57,794</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row3_col3" class="data row3 col3" >199</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row3_col4" class="data row3 col4" >8,000</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row3_col5" class="data row3 col5" >462,352,000</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row3_col6" class="data row3 col6" >290.42</td>
#             </tr>
#             <tr>
#                         <th id="T_90c592f4_41a6_11ea_865e_abae71f60986level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row4_col0" class="data row4 col0" >Andorra</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row4_col1" class="data row4 col1" >WESTERN EUROPE</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row4_col2" class="data row4 col2" >71,201</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row4_col3" class="data row4 col3" >468</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row4_col4" class="data row4 col4" >19,000</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row4_col5" class="data row4 col5" >1,352,819,000</td>
#                         <td id="T_90c592f4_41a6_11ea_865e_abae71f60986row4_col6" class="data row4 col6" >152.14</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('data-sci\\countries_info.csv')

df = df.head(5)

a = lambda frame: frame['Population'] * frame['GDP_USD_per_capita']
b = lambda frame: frame['Population'] / frame['Area_sq_mi']

df2 = df.assign(GDP_USD=a, Pop_density_per_sq_mi=b)
                
#display(df2)
    
style = df2.style.format('{:,.0f}', 
                         subset=pd.IndexSlice[:, 'Population':'GDP_USD'])

style.format({'Pop_density_per_sq_mi':'{:,.2f}'})

display(style)
# Out:
# <style  type="text/css" >
# </style><table id="T_f2abbf9a_41ca_11ea_9677_abae71f60986" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country</th>        <th class="col_heading level0 col1" >Region</th>        <th class="col_heading level0 col2" >Population</th>        <th class="col_heading level0 col3" >Area_sq_mi</th>        <th class="col_heading level0 col4" >GDP_USD_per_capita</th>        <th class="col_heading level0 col5" >GDP_USD</th>        <th class="col_heading level0 col6" >Pop_density_per_sq_mi</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f2abbf9a_41ca_11ea_9677_abae71f60986level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row0_col0" class="data row0 col0" >Afghanistan</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row0_col1" class="data row0 col1" >ASIA (EX. NEAR EAST)</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row0_col2" class="data row0 col2" >31,056,997</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row0_col3" class="data row0 col3" >647,500</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row0_col4" class="data row0 col4" >700</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row0_col5" class="data row0 col5" >21,739,897,900</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row0_col6" class="data row0 col6" >47.96</td>
#             </tr>
#             <tr>
#                         <th id="T_f2abbf9a_41ca_11ea_9677_abae71f60986level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row1_col0" class="data row1 col0" >Albania</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row1_col1" class="data row1 col1" >EASTERN EUROPE</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row1_col2" class="data row1 col2" >3,581,655</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row1_col3" class="data row1 col3" >28,748</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row1_col4" class="data row1 col4" >4,500</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row1_col5" class="data row1 col5" >16,117,447,500</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row1_col6" class="data row1 col6" >124.59</td>
#             </tr>
#             <tr>
#                         <th id="T_f2abbf9a_41ca_11ea_9677_abae71f60986level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row2_col0" class="data row2 col0" >Algeria</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row2_col1" class="data row2 col1" >NORTHERN AFRICA</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row2_col2" class="data row2 col2" >32,930,091</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row2_col3" class="data row2 col3" >2,381,740</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row2_col4" class="data row2 col4" >6,000</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row2_col5" class="data row2 col5" >197,580,546,000</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row2_col6" class="data row2 col6" >13.83</td>
#             </tr>
#             <tr>
#                         <th id="T_f2abbf9a_41ca_11ea_9677_abae71f60986level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row3_col0" class="data row3 col0" >American Samoa</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row3_col1" class="data row3 col1" >OCEANIA</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row3_col2" class="data row3 col2" >57,794</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row3_col3" class="data row3 col3" >199</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row3_col4" class="data row3 col4" >8,000</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row3_col5" class="data row3 col5" >462,352,000</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row3_col6" class="data row3 col6" >290.42</td>
#             </tr>
#             <tr>
#                         <th id="T_f2abbf9a_41ca_11ea_9677_abae71f60986level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row4_col0" class="data row4 col0" >Andorra</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row4_col1" class="data row4 col1" >WESTERN EUROPE</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row4_col2" class="data row4 col2" >71,201</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row4_col3" class="data row4 col3" >468</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row4_col4" class="data row4 col4" >19,000</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row4_col5" class="data row4 col5" >1,352,819,000</td>
#                         <td id="T_f2abbf9a_41ca_11ea_9677_abae71f60986row4_col6" class="data row4 col6" >152.14</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('data-sci\\countries_info.csv')

g = df.groupby(['Region'])[['Population', 'Area_sq_mi']].sum()

g = g.add_prefix('sum_')

display(g.style.format('{:,}'))
# Out:
# <style  type="text/css" >
# </style><table id="T_af4c96d4_41a7_11ea_bef2_abae71f60986" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sum_Population</th>        <th class="col_heading level0 col1" >sum_Area_sq_mi</th>    </tr>    <tr>        <th class="index_name level0" >Region</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_af4c96d4_41a7_11ea_bef2_abae71f60986level0_row0" class="row_heading level0 row0" >ASIA (EX. NEAR EAST)</th>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row0_col0" class="data row0 col0" >3,687,982,236</td>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row0_col1" class="data row0 col1" >23,096,712</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c96d4_41a7_11ea_bef2_abae71f60986level0_row1" class="row_heading level0 row1" >BALTICS</th>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row1_col0" class="data row1 col0" >7,184,974</td>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row1_col1" class="data row1 col1" >175,015</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c96d4_41a7_11ea_bef2_abae71f60986level0_row2" class="row_heading level0 row2" >C.W. OF IND. STATES</th>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row2_col0" class="data row2 col0" >280,081,548</td>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row2_col1" class="data row2 col1" >22,100,843</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c96d4_41a7_11ea_bef2_abae71f60986level0_row3" class="row_heading level0 row3" >EASTERN EUROPE</th>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row3_col0" class="data row3 col0" >119,914,717</td>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row3_col1" class="data row3 col1" >1,152,222</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c96d4_41a7_11ea_bef2_abae71f60986level0_row4" class="row_heading level0 row4" >LATIN AMER. & CARIB</th>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row4_col0" class="data row4 col0" >561,824,599</td>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row4_col1" class="data row4 col1" >20,544,084</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c96d4_41a7_11ea_bef2_abae71f60986level0_row5" class="row_heading level0 row5" >NEAR EAST</th>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row5_col0" class="data row5 col0" >195,068,377</td>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row5_col1" class="data row5 col1" >4,355,586</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c96d4_41a7_11ea_bef2_abae71f60986level0_row6" class="row_heading level0 row6" >NORTHERN AFRICA</th>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row6_col0" class="data row6 col0" >161,407,133</td>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row6_col1" class="data row6 col1" >6,018,890</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c96d4_41a7_11ea_bef2_abae71f60986level0_row7" class="row_heading level0 row7" >NORTHERN AMERICA</th>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row7_col0" class="data row7 col0" >331,672,307</td>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row7_col1" class="data row7 col1" >21,782,471</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c96d4_41a7_11ea_bef2_abae71f60986level0_row8" class="row_heading level0 row8" >OCEANIA</th>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row8_col0" class="data row8 col0" >33,131,662</td>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row8_col1" class="data row8 col1" >8,519,812</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c96d4_41a7_11ea_bef2_abae71f60986level0_row9" class="row_heading level0 row9" >SUB-SAHARAN AFRICA</th>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row9_col0" class="data row9 col0" >749,437,000</td>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row9_col1" class="data row9 col1" >24,341,406</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c96d4_41a7_11ea_bef2_abae71f60986level0_row10" class="row_heading level0 row10" >WESTERN EUROPE</th>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row10_col0" class="data row10 col0" >396,339,998</td>
#                         <td id="T_af4c96d4_41a7_11ea_bef2_abae71f60986row10_col1" class="data row10 col1" >3,710,478</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('data-sci\\countries_info.csv')

g = df.groupby(['Region']).agg({'Population':[max, min], 
                                'GDP_USD_per_capita':[max, min]})

display(g.style.format('{:,}'))
# Out:
# <style  type="text/css" >
# </style><table id="T_3481d7c2_4103_11ea_9a9a_abae71f60986" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>Population</th>        <th class="col_heading level0 col2" colspan=2>GDP_USD_per_capita</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >max</th>        <th class="col_heading level1 col1" >min</th>        <th class="col_heading level1 col2" >max</th>        <th class="col_heading level1 col3" >min</th>    </tr>    <tr>        <th class="index_name level0" >Region</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3481d7c2_4103_11ea_9a9a_abae71f60986level0_row0" class="row_heading level0 row0" >ASIA (EX. NEAR EAST)</th>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row0_col0" class="data row0 col0" >1,313,973,713</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row0_col1" class="data row0 col1" >359,008</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row0_col2" class="data row0 col2" >28,800.0</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row0_col3" class="data row0 col3" >500.0</td>
#             </tr>
#             <tr>
#                         <th id="T_3481d7c2_4103_11ea_9a9a_abae71f60986level0_row1" class="row_heading level0 row1" >BALTICS</th>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row1_col0" class="data row1 col0" >3,585,906</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row1_col1" class="data row1 col1" >1,324,333</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row1_col2" class="data row1 col2" >12,300.0</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row1_col3" class="data row1 col3" >10,200.0</td>
#             </tr>
#             <tr>
#                         <th id="T_3481d7c2_4103_11ea_9a9a_abae71f60986level0_row2" class="row_heading level0 row2" >C.W. OF IND. STATES</th>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row2_col0" class="data row2 col0" >142,893,540</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row2_col1" class="data row2 col1" >2,976,372</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row2_col2" class="data row2 col2" >8,900.0</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row2_col3" class="data row2 col3" >1,000.0</td>
#             </tr>
#             <tr>
#                         <th id="T_3481d7c2_4103_11ea_9a9a_abae71f60986level0_row3" class="row_heading level0 row3" >EASTERN EUROPE</th>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row3_col0" class="data row3 col0" >38,536,869</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row3_col1" class="data row3 col1" >2,010,347</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row3_col2" class="data row3 col2" >19,000.0</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row3_col3" class="data row3 col3" >2,200.0</td>
#             </tr>
#             <tr>
#                         <th id="T_3481d7c2_4103_11ea_9a9a_abae71f60986level0_row4" class="row_heading level0 row4" >LATIN AMER. & CARIB</th>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row4_col0" class="data row4 col0" >188,078,227</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row4_col1" class="data row4 col1" >9,439</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row4_col2" class="data row4 col2" >35,000.0</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row4_col3" class="data row4 col3" >1,600.0</td>
#             </tr>
#             <tr>
#                         <th id="T_3481d7c2_4103_11ea_9a9a_abae71f60986level0_row5" class="row_heading level0 row5" >NEAR EAST</th>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row5_col0" class="data row5 col0" >70,413,958</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row5_col1" class="data row5 col1" >698,585</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row5_col2" class="data row5 col2" >23,200.0</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row5_col3" class="data row5 col3" >600.0</td>
#             </tr>
#             <tr>
#                         <th id="T_3481d7c2_4103_11ea_9a9a_abae71f60986level0_row6" class="row_heading level0 row6" >NORTHERN AFRICA</th>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row6_col0" class="data row6 col0" >78,887,007</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row6_col1" class="data row6 col1" >273,008</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row6_col2" class="data row6 col2" >6,900.0</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row6_col3" class="data row6 col3" >4,000.0</td>
#             </tr>
#             <tr>
#                         <th id="T_3481d7c2_4103_11ea_9a9a_abae71f60986level0_row7" class="row_heading level0 row7" >NORTHERN AMERICA</th>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row7_col0" class="data row7 col0" >298,444,215</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row7_col1" class="data row7 col1" >7,026</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row7_col2" class="data row7 col2" >37,800.0</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row7_col3" class="data row7 col3" >6,900.0</td>
#             </tr>
#             <tr>
#                         <th id="T_3481d7c2_4103_11ea_9a9a_abae71f60986level0_row8" class="row_heading level0 row8" >OCEANIA</th>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row8_col0" class="data row8 col0" >20,264,082</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row8_col1" class="data row8 col1" >11,810</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row8_col2" class="data row8 col2" >29,000.0</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row8_col3" class="data row8 col3" >800.0</td>
#             </tr>
#             <tr>
#                         <th id="T_3481d7c2_4103_11ea_9a9a_abae71f60986level0_row9" class="row_heading level0 row9" >SUB-SAHARAN AFRICA</th>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row9_col0" class="data row9 col0" >131,859,731</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row9_col1" class="data row9 col1" >7,502</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row9_col2" class="data row9 col2" >11,400.0</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row9_col3" class="data row9 col3" >500.0</td>
#             </tr>
#             <tr>
#                         <th id="T_3481d7c2_4103_11ea_9a9a_abae71f60986level0_row10" class="row_heading level0 row10" >WESTERN EUROPE</th>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row10_col0" class="data row10 col0" >82,422,299</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row10_col1" class="data row10 col1" >27,928</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row10_col2" class="data row10 col2" >55,100.0</td>
#                         <td id="T_3481d7c2_4103_11ea_9a9a_abae71f60986row10_col3" class="data row10 col3" >17,500.0</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('data-sci\\countries_info.csv')

df.pivot_table(aggfunc=[max, min],
               values=['Population', 'GDP_USD_per_capita'],
               index=['Region'],
               margins=False)
# Out:
#                                     max                            min  \
#                      GDP_USD_per_capita  Population GDP_USD_per_capita
# Region
# ASIA (EX. NEAR EAST)            28800.0  1313973713              500.0
# BALTICS                         12300.0     3585906            10200.0
# C.W. OF IND. STATES              8900.0   142893540             1000.0
# EASTERN EUROPE                  19000.0    38536869             2200.0
# LATIN AMER. & CARIB             35000.0   188078227             1600.0
# NEAR EAST                       23200.0    70413958              600.0
# NORTHERN AFRICA                  6900.0    78887007             4000.0
# NORTHERN AMERICA                37800.0   298444215             6900.0
# OCEANIA                         29000.0    20264082              800.0
# SUB-SAHARAN AFRICA              11400.0   131859731              500.0
# WESTERN EUROPE                  55100.0    82422299            17500.0
#
#
#                      Population
# Region
# ASIA (EX. NEAR EAST)     359008
# BALTICS                 1324333
# C.W. OF IND. STATES     2976372
# EASTERN EUROPE          2010347
# LATIN AMER. & CARIB        9439
# NEAR EAST                698585
# NORTHERN AFRICA          273008
# NORTHERN AMERICA           7026
# OCEANIA                   11810
# SUB-SAHARAN AFRICA         7502
# WESTERN EUROPE            27928

# %%
import pandas as pd

df = pd.read_csv('data-sci\\countries_info.csv')

#เรียงลำดับข้อมูลจากมากไปหาน้อย โดยใช้คอลัมน์เป้าหมายที่หาค่าสูงสุดเป็นเกณฑ์
df_sorted = df.sort_values(by='GDP_USD_per_capita', ascending=False)

#แบ่งกลุ่มตามภูมิภาคแล้วเลือกข้อมูล 3 ลำดับแรกของแต่ละกลุ่ม
df_grp_by_reg = df_sorted.groupby(['Region']).head(3)

#display(df_grp_by_reg)

#จัดกลุ่มอีกครั้ง โดยใช้ภูมิภาคและประเทศในการจัดกลุ่ม
#แล้วแสดงผลรวมของแต่ละกลุ่ม ในแบบ Aggregate Function 
#เพื่อหาผลรวมเฉพาะคอลัมน์ GDP 
g = df_grp_by_reg \
        .groupby(['Region', 'Country']) \
        .agg({'GDP_USD_per_capita':max}) \
        .add_prefix('max_')

#หรือแบบนี้ก็ได้
#g = df_grp_by_reg \
#        .groupby(['Region', 'Country'])[['GDP_USD_per_capita']] \
#        .max().add_prefix('max_')

#ถ้าต้องการแยกแสดงผลทีละส่วน พร้อมจัดสไตล์
display(g[:9].style.format('{:,}'), 
        g[9:18].style.format('{:,}'),
        g[18:27].style.format('{:,}'),
        g[27:].style.format('{:,}'))
# Out:
# <style  type="text/css" >
# </style><table id="T_4328ddfe_41cc_11ea_8305_abae71f60986" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_GDP_USD_per_capita</th>    </tr>    <tr>        <th class="index_name level0" >Region</th>        <th class="index_name level1" >Country</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4328ddfe_41cc_11ea_8305_abae71f60986level0_row0" class="row_heading level0 row0" rowspan=3>ASIA (EX. NEAR EAST)</th>
#                         <th id="T_4328ddfe_41cc_11ea_8305_abae71f60986level1_row0" class="row_heading level1 row0" >Hong Kong</th>
#                         <td id="T_4328ddfe_41cc_11ea_8305_abae71f60986row0_col0" class="data row0 col0" >28,800.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_4328ddfe_41cc_11ea_8305_abae71f60986level1_row1" class="row_heading level1 row1" >Japan</th>
#                         <td id="T_4328ddfe_41cc_11ea_8305_abae71f60986row1_col0" class="data row1 col0" >28,200.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_4328ddfe_41cc_11ea_8305_abae71f60986level1_row2" class="row_heading level1 row2" >Singapore</th>
#                         <td id="T_4328ddfe_41cc_11ea_8305_abae71f60986row2_col0" class="data row2 col0" >23,700.0</td>
#             </tr>
#             <tr>
#                         <th id="T_4328ddfe_41cc_11ea_8305_abae71f60986level0_row3" class="row_heading level0 row3" rowspan=3>BALTICS</th>
#                         <th id="T_4328ddfe_41cc_11ea_8305_abae71f60986level1_row3" class="row_heading level1 row3" >Estonia</th>
#                         <td id="T_4328ddfe_41cc_11ea_8305_abae71f60986row3_col0" class="data row3 col0" >12,300.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_4328ddfe_41cc_11ea_8305_abae71f60986level1_row4" class="row_heading level1 row4" >Latvia</th>
#                         <td id="T_4328ddfe_41cc_11ea_8305_abae71f60986row4_col0" class="data row4 col0" >10,200.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_4328ddfe_41cc_11ea_8305_abae71f60986level1_row5" class="row_heading level1 row5" >Lithuania</th>
#                         <td id="T_4328ddfe_41cc_11ea_8305_abae71f60986row5_col0" class="data row5 col0" >11,400.0</td>
#             </tr>
#             <tr>
#                         <th id="T_4328ddfe_41cc_11ea_8305_abae71f60986level0_row6" class="row_heading level0 row6" rowspan=3>C.W. OF IND. STATES</th>
#                         <th id="T_4328ddfe_41cc_11ea_8305_abae71f60986level1_row6" class="row_heading level1 row6" >Belarus</th>
#                         <td id="T_4328ddfe_41cc_11ea_8305_abae71f60986row6_col0" class="data row6 col0" >6,100.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_4328ddfe_41cc_11ea_8305_abae71f60986level1_row7" class="row_heading level1 row7" >Kazakhstan</th>
#                         <td id="T_4328ddfe_41cc_11ea_8305_abae71f60986row7_col0" class="data row7 col0" >6,300.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_4328ddfe_41cc_11ea_8305_abae71f60986level1_row8" class="row_heading level1 row8" >Russia</th>
#                         <td id="T_4328ddfe_41cc_11ea_8305_abae71f60986row8_col0" class="data row8 col0" >8,900.0</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_43298dac_41cc_11ea_b825_abae71f60986" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_GDP_USD_per_capita</th>    </tr>    <tr>        <th class="index_name level0" >Region</th>        <th class="index_name level1" >Country</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_43298dac_41cc_11ea_b825_abae71f60986level0_row0" class="row_heading level0 row0" rowspan=3>EASTERN EUROPE</th>
#                         <th id="T_43298dac_41cc_11ea_b825_abae71f60986level1_row0" class="row_heading level1 row0" >Czech Republic</th>
#                         <td id="T_43298dac_41cc_11ea_b825_abae71f60986row0_col0" class="data row0 col0" >15,700.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_43298dac_41cc_11ea_b825_abae71f60986level1_row1" class="row_heading level1 row1" >Hungary</th>
#                         <td id="T_43298dac_41cc_11ea_b825_abae71f60986row1_col0" class="data row1 col0" >13,900.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_43298dac_41cc_11ea_b825_abae71f60986level1_row2" class="row_heading level1 row2" >Slovenia</th>
#                         <td id="T_43298dac_41cc_11ea_b825_abae71f60986row2_col0" class="data row2 col0" >19,000.0</td>
#             </tr>
#             <tr>
#                         <th id="T_43298dac_41cc_11ea_b825_abae71f60986level0_row3" class="row_heading level0 row3" rowspan=3>LATIN AMER. & CARIB</th>
#                         <th id="T_43298dac_41cc_11ea_b825_abae71f60986level1_row3" class="row_heading level1 row3" >Aruba</th>
#                         <td id="T_43298dac_41cc_11ea_b825_abae71f60986row3_col0" class="data row3 col0" >28,000.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_43298dac_41cc_11ea_b825_abae71f60986level1_row4" class="row_heading level1 row4" >Cayman Islands</th>
#                         <td id="T_43298dac_41cc_11ea_b825_abae71f60986row4_col0" class="data row4 col0" >35,000.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_43298dac_41cc_11ea_b825_abae71f60986level1_row5" class="row_heading level1 row5" >Virgin Islands</th>
#                         <td id="T_43298dac_41cc_11ea_b825_abae71f60986row5_col0" class="data row5 col0" >17,200.0</td>
#             </tr>
#             <tr>
#                         <th id="T_43298dac_41cc_11ea_b825_abae71f60986level0_row6" class="row_heading level0 row6" rowspan=3>NEAR EAST</th>
#                         <th id="T_43298dac_41cc_11ea_b825_abae71f60986level1_row6" class="row_heading level1 row6" >Israel</th>
#                         <td id="T_43298dac_41cc_11ea_b825_abae71f60986row6_col0" class="data row6 col0" >19,800.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_43298dac_41cc_11ea_b825_abae71f60986level1_row7" class="row_heading level1 row7" >Qatar</th>
#                         <td id="T_43298dac_41cc_11ea_b825_abae71f60986row7_col0" class="data row7 col0" >21,500.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_43298dac_41cc_11ea_b825_abae71f60986level1_row8" class="row_heading level1 row8" >United Arab Emirates</th>
#                         <td id="T_43298dac_41cc_11ea_b825_abae71f60986row8_col0" class="data row8 col0" >23,200.0</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_432a6dba_41cc_11ea_a134_abae71f60986" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_GDP_USD_per_capita</th>    </tr>    <tr>        <th class="index_name level0" >Region</th>        <th class="index_name level1" >Country</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_432a6dba_41cc_11ea_a134_abae71f60986level0_row0" class="row_heading level0 row0" rowspan=3>NORTHERN AFRICA</th>
#                         <th id="T_432a6dba_41cc_11ea_a134_abae71f60986level1_row0" class="row_heading level1 row0" >Algeria</th>
#                         <td id="T_432a6dba_41cc_11ea_a134_abae71f60986row0_col0" class="data row0 col0" >6,000.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_432a6dba_41cc_11ea_a134_abae71f60986level1_row1" class="row_heading level1 row1" >Libya</th>
#                         <td id="T_432a6dba_41cc_11ea_a134_abae71f60986row1_col0" class="data row1 col0" >6,400.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_432a6dba_41cc_11ea_a134_abae71f60986level1_row2" class="row_heading level1 row2" >Tunisia</th>
#                         <td id="T_432a6dba_41cc_11ea_a134_abae71f60986row2_col0" class="data row2 col0" >6,900.0</td>
#             </tr>
#             <tr>
#                         <th id="T_432a6dba_41cc_11ea_a134_abae71f60986level0_row3" class="row_heading level0 row3" rowspan=3>NORTHERN AMERICA</th>
#                         <th id="T_432a6dba_41cc_11ea_a134_abae71f60986level1_row3" class="row_heading level1 row3" >Bermuda</th>
#                         <td id="T_432a6dba_41cc_11ea_a134_abae71f60986row3_col0" class="data row3 col0" >36,000.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_432a6dba_41cc_11ea_a134_abae71f60986level1_row4" class="row_heading level1 row4" >Canada</th>
#                         <td id="T_432a6dba_41cc_11ea_a134_abae71f60986row4_col0" class="data row4 col0" >29,800.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_432a6dba_41cc_11ea_a134_abae71f60986level1_row5" class="row_heading level1 row5" >United States</th>
#                         <td id="T_432a6dba_41cc_11ea_a134_abae71f60986row5_col0" class="data row5 col0" >37,800.0</td>
#             </tr>
#             <tr>
#                         <th id="T_432a6dba_41cc_11ea_a134_abae71f60986level0_row6" class="row_heading level0 row6" rowspan=3>OCEANIA</th>
#                         <th id="T_432a6dba_41cc_11ea_a134_abae71f60986level1_row6" class="row_heading level1 row6" >Australia</th>
#                         <td id="T_432a6dba_41cc_11ea_a134_abae71f60986row6_col0" class="data row6 col0" >29,000.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_432a6dba_41cc_11ea_a134_abae71f60986level1_row7" class="row_heading level1 row7" >Guam</th>
#                         <td id="T_432a6dba_41cc_11ea_a134_abae71f60986row7_col0" class="data row7 col0" >21,000.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_432a6dba_41cc_11ea_a134_abae71f60986level1_row8" class="row_heading level1 row8" >New Zealand</th>
#                         <td id="T_432a6dba_41cc_11ea_a134_abae71f60986row8_col0" class="data row8 col0" >21,600.0</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_432b4eee_41cc_11ea_af54_abae71f60986" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_GDP_USD_per_capita</th>    </tr>    <tr>        <th class="index_name level0" >Region</th>        <th class="index_name level1" >Country</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_432b4eee_41cc_11ea_af54_abae71f60986level0_row0" class="row_heading level0 row0" rowspan=3>SUB-SAHARAN AFRICA</th>
#                         <th id="T_432b4eee_41cc_11ea_af54_abae71f60986level1_row0" class="row_heading level1 row0" >Botswana</th>
#                         <td id="T_432b4eee_41cc_11ea_af54_abae71f60986row0_col0" class="data row0 col0" >9,000.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_432b4eee_41cc_11ea_af54_abae71f60986level1_row1" class="row_heading level1 row1" >Mauritius</th>
#                         <td id="T_432b4eee_41cc_11ea_af54_abae71f60986row1_col0" class="data row1 col0" >11,400.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_432b4eee_41cc_11ea_af54_abae71f60986level1_row2" class="row_heading level1 row2" >South Africa</th>
#                         <td id="T_432b4eee_41cc_11ea_af54_abae71f60986row2_col0" class="data row2 col0" >10,700.0</td>
#             </tr>
#             <tr>
#                         <th id="T_432b4eee_41cc_11ea_af54_abae71f60986level0_row3" class="row_heading level0 row3" rowspan=3>WESTERN EUROPE</th>
#                         <th id="T_432b4eee_41cc_11ea_af54_abae71f60986level1_row3" class="row_heading level1 row3" >Luxembourg</th>
#                         <td id="T_432b4eee_41cc_11ea_af54_abae71f60986row3_col0" class="data row3 col0" >55,100.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_432b4eee_41cc_11ea_af54_abae71f60986level1_row4" class="row_heading level1 row4" >Norway</th>
#                         <td id="T_432b4eee_41cc_11ea_af54_abae71f60986row4_col0" class="data row4 col0" >37,800.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_432b4eee_41cc_11ea_af54_abae71f60986level1_row5" class="row_heading level1 row5" >San Marino</th>
#                         <td id="T_432b4eee_41cc_11ea_af54_abae71f60986row5_col0" class="data row5 col0" >34,600.0</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data-sci\\countries_info.csv')

countries = ['Thailand', 'Malaysia', 'Singapore', 
             'Indonesia', 'Vietnam', 'Philippines']
gdps = []

for i, c in enumerate(countries):
    idx = df[df.Country == countries[i]].index
    g = df.at[idx[0], 'GDP_USD_per_capita']
    gdps.append(g)

plt.bar(countries, gdps, color=['r', 'b', 'g', 'm', 'y', 'k'])
plt.xticks(rotation=60)
plt.title('ASEAN GDP per capita (USD)')
plt.show()
